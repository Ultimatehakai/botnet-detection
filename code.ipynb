# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('D:\degree\sem 6\dataset.csv')

# %%
df.columns
# Out:
# Index(['Destination Port', 'Flow Duration',
#        'Total Fwd PacketsTotal Backward Packets', 'Unnamed: 3',
#        'Total Length of Fwd Packets', 'Fwd Packet Length Max',
#        'Fwd Packet Length Min', 'Fwd Packet Length Mean',
#        'Fwd Packet Length Std  ', 'Label'],
#       dtype='object')

# %%
df.head()
# Out:
#    Destination Port  Flow Duration  Total Fwd PacketsTotal Backward Packets  \
# 0             54865              3                                        2
# 1             55054            109                                        1
# 2             46236             34                                        1
# 3             61374             61                                        1
# 4             61326             68                                        1
#
#    Unnamed: 3  Total Length of Fwd Packets  Fwd Packet Length Max  \
# 0           0                           12                      0
# 1           1                            6                      6
# 2           1                            6                      6
# 3           1                            6                      6
# 4           1                            6                      6
#
#    Fwd Packet Length Min  Fwd Packet Length Mean  Fwd Packet Length Std    \
# 0                      6                       6                        6
# 1                      6                       6                        6
# 2                      6                       6                        6
# 3                      6                       6                        6
# 4                      6                       6                        6
#
#     Label
# 0    safe
# 1  unsafe
# 2  unsafe
# 3  unsafe
# 4    safe

# %%
df.isnull().sum()
# Out:
# Destination Port                           0
# Flow Duration                              0
# Total Fwd PacketsTotal Backward Packets    0
# Unnamed: 3                                 0
# Total Length of Fwd Packets                0
# Fwd Packet Length Max                      0
# Fwd Packet Length Min                      0
# Fwd Packet Length Mean                     0
# Fwd Packet Length Std                      0
# Label                                      0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 10 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Destination Port                         5 non-null      int64
#  1   Flow Duration                            5 non-null      int64
#  2   Total Fwd PacketsTotal Backward Packets  5 non-null      int64
#  3   Unnamed: 3                               5 non-null      int64
#  4   Total Length of Fwd Packets              5 non-null      int64
#  5   Fwd Packet Length Max                    5 non-null      int64
#  6   Fwd Packet Length Min                    5 non-null      int64
#  7   Fwd Packet Length Mean                   5 non-null      int64
#  8   Fwd Packet Length Std                    5 non-null      int64
#  9   Label                                    5 non-null      object
# dtypes: int64(9), object(1)
# memory usage: 532.0+ bytes

# %%
df
# Out:
#    Destination Port  Flow Duration  Total Fwd PacketsTotal Backward Packets  \
# 0             54865              3                                        2
# 1             55054            109                                        1
# 2             46236             34                                        1
# 3             61374             61                                        1
# 4             61326             68                                        1
#
#    Unnamed: 3  Total Length of Fwd Packets  Fwd Packet Length Max  \
# 0           0                           12                      0
# 1           1                            6                      6
# 2           1                            6                      6
# 3           1                            6                      6
# 4           1                            6                      6
#
#    Fwd Packet Length Min  Fwd Packet Length Mean  Fwd Packet Length Std    \
# 0                      6                       6                        6
# 1                      6                       6                        6
# 2                      6                       6                        6
# 3                      6                       6                        6
# 4                      6                       6                        6
#
#     Label
# 0    safe
# 1  unsafe
# 2  unsafe
# 3  unsafe
# 4    safe

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encoder = LabelEncoder()
df[' Label']=encoder.fit_transform(df['Label'])

# %%
df.head(10)
# Out:
#    Destination Port  Flow Duration  Total Fwd PacketsTotal Backward Packets  \
# 0             54865              3                                        2
# 1             55054            109                                        1
# 2             46236             34                                        1
# 3             61374             61                                        1
# 4             61326             68                                        1
#
#    Unnamed: 3  Total Length of Fwd Packets  Fwd Packet Length Max  \
# 0           0                           12                      0
# 1           1                            6                      6
# 2           1                            6                      6
# 3           1                            6                      6
# 4           1                            6                      6
#
#    Fwd Packet Length Min  Fwd Packet Length Mean  Fwd Packet Length Std    \
# 0                      6                       6                        6
# 1                      6                       6                        6
# 2                      6                       6                        6
# 3                      6                       6                        6
# 4                      6                       6                        6
#
#     Label   Label
# 0    safe       0
# 1  unsafe       1
# 2  unsafe       1
# 3  unsafe       1
# 4    safe       0

# %%
from sklearn.feature_selection import SelectKBest,chi2
from sklearn.model_selection import train_test_split

# %%
Target= ' Label'
X = df.loc[:,df.columns !=Target]
y = df.loc[:,Target]

# %%
#from sklearn.impute import SimpleImputer
#lower_bound=0
#upper_bound=100
#X_clipped = np.clip(X, lower_bound, upper_bound) 
#imputer = SimpleImputer(strategy='mean')
#X_imputed = imputer.fit_transform(X_clipped)

# %%
import pandas as pd

# Assuming df is your DataFrame
print(df.columns)  # Check column names of df

# Verify column names specified in selected_features


# Check for typos and ensure column names match exactly
# Double-check the column names in the DataFrame
print(df.head())  # Print first few rows of the DataFrame

# Select the specified features from the DataFrame

from sklearn.impute import SimpleImputer
#lower_bound=0
#upper_bound=100
#X_clipped = np.clip(X, lower_bound, upper_bound) 
imputer = SimpleImputer(strategy='mean')
X_imputed = imputer.fit_transform
# Print selected features
print(X.columns)
selector = SelectKBest(score_func=chi2, k=10)
selector.fit(X_imputed, y)
selected_features = selector.get_support(indices=True)
X_new = X_imputed[:, selected_features]
X_new_train, X_test, y_train, y_test = train_test_split(X_new, y, test_size=0.25)
selected_features=['Destination Port', ' Flow Duration', ' Total Fwd Packets',
       ' Total Backward Packets', 'Total Length of Fwd Packets',
       ' Total Length of Bwd Packets', ' Fwd Packet Length Max',
       ' Fwd Packet Length Min', ' Fwd Packet Length Mean',
       ' Fwd Packet Length Std']
X = df[selected_features]
print(selected_features)

# %%
print(X)
# Out:
#    Destination Port  Flow Duration  Total Fwd PacketsTotal Backward Packets  \
# 0             54865              3                                        2
# 1             55054            109                                        1
# 2             46236             34                                        1
# 3             61374             61                                        1
# 4             61326             68                                        1
#
#    Unnamed: 3  Total Length of Fwd Packets  Fwd Packet Length Max  \
# 0           0                           12                      0
# 1           1                            6                      6
# 2           1                            6                      6
# 3           1                            6                      6
# 4           1                            6                      6
#
#    Fwd Packet Length Min  Fwd Packet Length Mean  Fwd Packet Length Std    \
# 0                      6                       6                        6
# 1                      6                       6                        6
# 2                      6                       6                        6
# 3                      6                       6                        6
# 4                      6                       6                        6
#
#     Label
# 0    safe
# 1  unsafe
# 2  unsafe
# 3  unsafe
# 4    safe

# %%
X_new
# Out:
# array([[5.4865e+04, 3.0000e+00, 2.0000e+00, 0.0000e+00, 1.2000e+01,
#         0.0000e+00, 6.0000e+00, 6.0000e+00, 6.0000e+00],
#        [5.5054e+04, 1.0900e+02, 1.0000e+00, 1.0000e+00, 6.0000e+00,
#         6.0000e+00, 6.0000e+00, 6.0000e+00, 6.0000e+00],
#        [4.6236e+04, 3.4000e+01, 1.0000e+00, 1.0000e+00, 6.0000e+00,
#         6.0000e+00, 6.0000e+00, 6.0000e+00, 6.0000e+00],
#        [6.1374e+04, 6.1000e+01, 1.0000e+00, 1.0000e+00, 6.0000e+00,
#         6.0000e+00, 6.0000e+00, 6.0000e+00, 6.0000e+00],
#        [6.1326e+04, 6.8000e+01, 1.0000e+00, 1.0000e+00, 6.0000e+00,
#         6.0000e+00, 6.0000e+00, 6.0000e+00, 6.0000e+00]])

# %%
y.unique
# Out:
# <bound method Series.unique of 0    0
# 1    1
# 2    1
# 3    1
# 4    0
# Name:  Label, dtype: int32>

# %%
from sklearn.tree import DecisionTreeClassifier
dtc=DecisionTreeClassifier()
dtc.fit(X_new_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred=dtc.predict(X_test)

# %%
y_pred[:10]
# Out:
# array([1, 0])

# %%
y_test
# Out:
# 4    0
# 2    1
# Name:  Label, dtype: int32

# %%
y_test[:10]
# Out:
# 4    0
# 2    1
# Name:  Label, dtype: int32

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error( y_test,y_pred)
# Out:
# 0.5

# %%
import joblib

# Assuming 'dtr' is your trained Decision Tree model

# Save the trained Decision Tree model
joblib.dump(dtc, 'decision_tree_model.pkl')
# Out:
# ['decision_tree_model.pkl']

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf_reg= RandomForestClassifier(n_estimators=500 )
rf_reg.fit(X_new_train,y_train)
# Out:
# RandomForestClassifier(n_estimators=500)

# %%
from sklearn.ensemble import RandomForestClassifier

# Initialize the RandomForestClassifier with max_depth parameter
model = RandomForestClassifier(max_depth=10)  # Set max_depth to the desired value, e.g., 10

# Train the model on your training data
model.fit(X_new_train, y_train)
# Out:
# RandomForestClassifier(max_depth=10)

# %%
y_pred=rf_reg.predict(X_test)

# %%
y_pred
# Out:
# array([1, 1])

# %%
y_pred = pd.DataFrame(data=y_pred,columns=['pred'])
y_pred
# Out:
#    pred
# 0     1
# 1     1

# %%
y_test
# Out:
# 4    0
# 2    1
# Name:  Label, dtype: int32

# %%
print(mean_squared_error(y_test,y_pred))
# Out:
# 0.5

# %%
import joblib
joblib.dump(rf_reg, 'model.pkl')
# Out:
# ['model.pkl']

# %%
pd.DataFrame(X_new_train)
# Out:
#          0      1    2    3     4    5    6    7    8
# 0  61374.0   61.0  1.0  1.0   6.0  6.0  6.0  6.0  6.0
# 1  55054.0  109.0  1.0  1.0   6.0  6.0  6.0  6.0  6.0
# 2  54865.0    3.0  2.0  0.0  12.0  0.0  6.0  6.0  6.0

# %%
y_train
# Out:
# 3    1
# 1    1
# 0    0
# Name:  Label, dtype: int32

# %%
np.nan_to_num(X)
# Out:
# array([[54865, 3, 2, 0, 12, 0, 6, 6, 6, 'safe'],
#        [55054, 109, 1, 1, 6, 6, 6, 6, 6, 'unsafe'],
#        [46236, 34, 1, 1, 6, 6, 6, 6, 6, 'unsafe'],
#        [61374, 61, 1, 1, 6, 6, 6, 6, 6, 'unsafe'],
#        [61326, 68, 1, 1, 6, 6, 6, 6, 6, 'safe']], dtype=object)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix,precision_score,recall_score,f1_score,roc_auc_score

# %%
models={
    "Decision Tree":DecisionTreeClassifier(),
    "Random Forest":RandomForestClassifier(),
    "Naive Bayes":GaussianNB(),
    "Logistic Regression":LogisticRegression()
}
for i in range(len(list(models))):
    model = list(models.values())[i]
    model.fit(X_new_train,y_train) #train model

    #make prediction
    y_train_pred =model.predict(X_new_train)
    y_test_pred =model.predict(X_test)

    #Training set performance
    model_train_accuracy = accuracy_score(y_train, y_train_pred)
    model_train_f1 = f1_score(y_train, y_train_pred, average='weighted')
    model_train_precision = precision_score(y_train, y_train_pred)
    model_train_recall = recall_score(y_train, y_train_pred)
    model_train_rocauc_score = roc_auc_score(y_train, y_train_pred)


    #Test set performance
    model_test_accuracy = accuracy_score(y_test, y_test_pred)
    model_test_f1 = f1_score(y_test, y_test_pred, average='weighted')
    model_test_precision = precision_score(y_test, y_test_pred)
    model_test_recall = recall_score(y_test, y_test_pred)
    model_test_rocauc_score = roc_auc_score(y_test, y_test_pred)


    print(list(models.keys())[i])

    print('Model performance for Tranning Set')
    print("- Accuracy: {:.4f}".format(model_train_accuracy))
    print("- F1 Score: {:.4f}".format(model_train_f1))  

    print("- Precision: {:.4f}".format(model_train_precision))
    print("- Recall: {:.4f}".format(model_train_recall))
    print("- Roc Auc Score: {:.4f}".format(model_train_rocauc_score))


    print('----------------------------------------------------------------')

    print('Model performance for Test set')
    print("- Accuracy: {:.4f}".format(model_test_accuracy))
    print("- F1 Score: {:.4f}".format(model_test_f1))  

    print("- Precision: {:.4f}".format(model_test_precision))
    print("- Recall: {:.4f}".format(model_test_recall))
    print("- Roc Auc Score: {:.4f}".format(model_test_rocauc_score))

    print('='*35)
    print('\n')
# Out:
# Decision Tree
# Model performance for Tranning Set
# - Accuracy: 1.0000
# - F1 Score: 1.0000
# - Precision: 1.0000
# - Recall: 1.0000
# - Roc Auc Score: 1.0000
# ----------------------------------------------------------------
# Model performance for Test set
# - Accuracy: 0.5000
# - F1 Score: 0.3333
# - Precision: 0.5000
# - Recall: 1.0000
# - Roc Auc Score: 0.5000
# ===================================
#
#
# Random Forest
# Model performance for Tranning Set
# - Accuracy: 1.0000
# - F1 Score: 1.0000
# - Precision: 1.0000
# - Recall: 1.0000
# - Roc Auc Score: 1.0000
# ----------------------------------------------------------------
# Model performance for Test set
# - Accuracy: 0.5000
# - F1 Score: 0.3333
# - Precision: 0.5000
# - Recall: 1.0000
# - Roc Auc Score: 0.5000
# ===================================
#
#
# Naive Bayes
# Model performance for Tranning Set
# - Accuracy: 1.0000
# - F1 Score: 1.0000
# - Precision: 1.0000
# - Recall: 1.0000
# - Roc Auc Score: 1.0000
# ----------------------------------------------------------------
# Model performance for Test set
# - Accuracy: 0.5000
# - F1 Score: 0.3333
# - Precision: 0.5000
# - Recall: 1.0000
# - Roc Auc Score: 0.5000
# ===================================
#
#
# Logistic Regression
# Model performance for Tranning Set
# - Accuracy: 1.0000
# - F1 Score: 1.0000
# - Precision: 1.0000
# - Recall: 1.0000
# - Roc Auc Score: 1.0000
# ----------------------------------------------------------------
# Model performance for Test set
# - Accuracy: 0.5000
# - F1 Score: 0.3333
# - Precision: 0.5000
# - Recall: 1.0000
# - Roc Auc Score: 0.5000
# ===================================

# %%
import pandas as pd
df = pd.read_csv('C:\\Users\\Bhushan\\Desktop\\botnet project\\Friday-WorkingHours-Afternoon-DDos.pcap_ISCX.csv')
selected_features=['Destination Port', ' Flow Duration', ' Total Fwd Packets',
       ' Total Backward Packets', 'Total Length of Fwd Packets',
       ' Total Length of Bwd Packets', ' Fwd Packet Length Max',
       ' Fwd Packet Length Min', ' Fwd Packet Length Mean',
       ' Fwd Packet Length Std']
X = df[selected_features]
print(selected_features)
# Out:
# ['Destination Port', ' Flow Duration', ' Total Fwd Packets', ' Total Backward Packets', 'Total Length of Fwd Packets', ' Total Length of Bwd Packets', ' Fwd Packet Length Max', ' Fwd Packet Length Min', ' Fwd Packet Length Mean', ' Fwd Packet Length Std']

# %%
print(len(selected_features))
# Out:
# 10
